# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_wine

# %%
wine_Data=load_wine()
feature=wine_Data['data']
df = pd.DataFrame(feature)
df.columns=wine_Data['feature_names']
df

#There are 13 columns in this dataset
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#checking if there is any null values in any of the columns
df.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
df.corr()
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
#                               alcalinity_of_ash  magnesium  total_phenols  \
# ...

# %%
plt.figure(figsize= (12,7))
sns.heatmap(df.corr() , annot= True)
plt.show()

# %% [markdown]
# #### Based on analysis, Total_phenols and flavonoids has more correlation, Hence dropping both the column 'flavanoids' and 'Total_Phenols'
#
# Not sure how to handle the negative corelation

# %%
plt.figure(figsize= (12 , 7))
sns.heatmap(df.drop(['flavanoids','total_phenols'] , axis=1).corr() , annot= True )

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data= df ,  )

# %% [markdown]
# #### Filtered with some of the columns based on the outliers assumption. Removed malic_acid , Total_phenols, Flavanoids

# %%
sns.pairplot(data=df, vars=('alcohol','ash','alcalinity_of_ash', 'magnesium','proanthocyanins', 'color_intensity','od280/od315_of_diluted_wines', 'proline'))

# %% [markdown]
# ## Based on Pair Plot, it looks like
# 1) alcohol has positive relationship between Color_intensity and Proline others are nearly zero or negative relationship.
# 2) malic_Acid has scattered more with other features.
# 3) ash has positive relationship with alcanlinity_of_ash
# 4) Magnesium and proline has zero correlation or negative and more outlier values compare to other features.
# 5) od280/od315_of_diluted_wines has positive relationship with proanthocyanins

# %%
sns.pairplot(data=df, vars=('total_phenols','flavanoids'))

# %% [markdown]
# # BoxPlot

# %%
sns.boxenplot(data=df[['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
       'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
       'proanthocyanins', 'color_intensity', 'hue',
       'od280/od315_of_diluted_wines', 'proline']])
x = plt.gca().xaxis


# rotate the tick labels for the x axis
for item in x.get_ticklabels():
    item.set_rotation(90)

# %% [markdown]
# ## Based on Box Plot,
# Magnesium  and Proline has outliers compare with other features.
# Checking the Boxenploat after removing Proline and Magnesium
# On Further Drill down, alcalnity_of_ash has outliers compare to other features

# %%
sns.boxenplot(data=df[['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash',
       'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
       'proanthocyanins', 'color_intensity', 'hue',
       'od280/od315_of_diluted_wines']])
x = plt.gca().xaxis


# rotate the tick labels for the x axis
for item in x.get_ticklabels():
    item.set_rotation(90)

# %%
sns.boxenplot(data=df[['malic_acid', 'ash',
       'total_phenols', 'flavanoids',
       'proanthocyanins',
       'od280/od315_of_diluted_wines']])
x = plt.gca().xaxis


# rotate the tick labels for the x axis
for item in x.get_ticklabels():
    item.set_rotation(90)

# %%
fig, ax = plt.subplots(3, 3, figsize=(15, 10))
for var, subplot in zip(df.columns, ax.flatten()):
    sns.boxplot(x=var, y='alcohol', data=df, ax=subplot)

# %% [markdown]
# ### Distplot

# %%
df.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %%
plt.figure()
fig, ax = plt.subplots(4, 4, figsize=(20, 10))
for var, subplot in zip(df.columns, ax.flatten()):
    sns.distplot(df[var], ax=subplot)

#1) alcohol            - Uniform Distribution
#2) Malic_acid         - Skewed Distribution
#3) ash                - Normal Distribution
#4) alcalinity_of_ash  - Normal Distribution
#5) magnesium          - Normal Distribution
#6) total_phenols      - Uniform Distribution
#7) flavanoids            Uniform Distribution
#8) nonflavanoid_phenols - Binomial Distribution
#9) proanthocyanins      - Normal Distribution
#10) color_intensity     - Skewed Distribution
#11) hue                 - Normal Distribution
#12) od315_of_diluted_wines
#13) proline              - Skewed Distribution
